# %% [markdown]
# 福島県の人口推移　2010,2015,2020.
# 森嶋成世（Naruse Morishima）

# %%
import geopandas as gpd
import contextily as ctx
import plotly.express as px

# set font
import matplotlib as mpl

# for Mac
#mpl.rc('font',family='Hiragino Maru Gothic Pro')

# for PC
mpl.rc('font',family='MS Gothic')

# %%
f2015 = gpd.read_file('A002005212015DDSWC07.zip')

# %%
f2010 = gpd.read_file('A002005212010DDSWC07.zip')

# %%
f2020 = gpd.read_file('A002005212020DDSWC07.zip')

# %%
f2010.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6846 entries, 0 to 6845
# Data columns (total 44 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    6846 non-null   object
#  1   PREF        6846 non-null   object
#  2   CITY        6846 non-null   object
#  3   S_AREA      6846 non-null   object
#  4   PREF_NAME   6846 non-null   object
#  5   CITY_NAME   6846 non-null   object
#  6   S_NAME      6836 non-null   object
#  7   KIGO_E      387 non-null    object
#  8   HCODE       6846 non-null   int64
#  9   AREA        6846 non-null   float64
#  10  PERIMETER   6846 non-null   float64
#  11  H22KAxx#    6846 non-null   int64
#  12  H22KAxx-ID  6846 non-null   int64
#  13  KEN         6846 non-null   object
#  14  KEN_NAME    6846 non-null   object
#  15  SITYO_NAME  0 non-null      float64
#  16  GST_NAME    6846 non-null   object
#  17  CSS_NAME    1747 non-null   object
# ...

# %%
ax1 = f2010.plot()

# %%
# population map
ax1 = f2010.plot(column='JINKO',
         legend=True)

# %%
# population map
ax2 = f2015.plot(column='JINKO',
         legend=True)

# %%
# population map
ax3 = f2020.plot(column='JINKO',
         legend=True)

# %% [markdown]
# 今日はここまで
# 空也君からラインは返ってきません
# 残りのタスクはこのマップをもとに
# タイトルや凡例、サイズ、色等を調整し、避難区域の人口の変化が見えるようにする。
# 来週の授業終了までにエクセルでも構わないからチャートを作る。
